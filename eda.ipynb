# %% [markdown]
# # GR 8 Project Proposal: Predicting Gamer Anxiety.
#
# ## Team Members
#
# - Max Song,
# - Joseph Trybala
# - Miko Wieczorek

# %% [markdown]
# ## Dataset Description
#
# The dataset we have chosen to work with is at an intersection of mental health and video games. Individuals who
# contributed to this dataset were asked to complete several base-level batteries of psychology questions which measure quantitatively things such as Generalized Anxiety Disorder to Social Phobia to Satisfaction With Life. In addition to these psychological evaluations other biographical data was collected alongside self-reported data regarding video game habits. The dataset has few fill-in questions, most were numerical or choice-based. Most (>99%) of the participants of this study came from reddit so this sample is extremely biased to individuals who utilize social media in addition to playing video games.
#
# The three psychological question batteries cover multiple aspects of the idea or trope of a “Gamer”. To better understand the psychological landscape of each gamer, three standardized assessment tool/survey results and individual scores were collected: the GAD-7, SPIN-17, and SWLS.  Each of the different questionnaires take slightly different approaches with how they evaluate each gamer’s anxiety.
#
# The GAD-7, which is an assessment tool for Generalized Anxiety Disorder (GAD) was provided alongside a bonus question: GAD_E, a self-assessment of how anxiety affects an individual with day-to-day life. The GAD-7 consists of 7 main questions that score numerically ranging from 0-3, while the last bonus question is one chosen response (in Likert fashion).  Scores for this questionnaire are provided in raw format, a social or psychological practitioner should be able to add the scores to determine true scoring and infer diagnosis based on performance. Ultimately, using the threshold score of 10, the GAD-7 has a sensitivity of 89% and a specificity of 82% for GAD. Moreover, it’s also moderately good at screening three other common anxiety disorders – panic disorder (sensitivity 74%; specificity 81%), social anxiety disorder (sensitivity 72%; specificity 80%), and post-traumatic stress disorder (sensitivity 66%; specificity 81%).
#
# The Social Phobia Inventory (SPIN) was administered to participants in this study and the scores were recorded as raw values. SPIN is normally administered as a 5 question battery, the version used for this study was SPIN-17 which is an extended battery. The extended SPIN questionnaire consists of 17 questions whose scale is rated over the past week and address each of the symptom domains of social anxiety disorder (e.g., fear, avoidance, and physiological arousal). The total SPIN score is calculated by summing all of the individual scores from each question. A score of 19 and above appears to suggest a possibility of social anxiety; the possible range is between 0 and 68.
#
# The Satisfaction With Life Scale (SWLS) is a five question assessment tool that is designed to measure global cognitive judgments of one’s own life satisfaction. Recipients of this questionnaire indicate how much they agree or disagree with each of the five questions, using a 7-point scale, ranging from “Strongly Agree” (7) to “Strongly Disagree” (1). Each gamer’s own judgments of their own life satisfaction are scored by adding each individual score for every question, totaling a sum of categories that range from “Extremely Satisfied” to “Extremely Dissatisfied.” The questions are designed in a way that, although not specific to areas of life such as finance or health, allow the gamer to integrate and weight their life areas in a way that suits them, when assessing each statement.
#
# Since each questionnaire is evaluated by looking at the summed total of scores, when looking at each assessment tool, the score total columns GAD_T, SWL_T, and SPIN_T will most likely be a key direction for further analysis.
# Additional numeric data includes the average amount of hours per week the participant plays video games as well as the average amount of hours game streams are consumed. Participant age is also included, this begins at 18 as the researchers understandably did not elect to include minors in the study. A single score from Single Item Narcissism Scale (SINS), which is a singular question asked to participants “on a scale of one to seven how much do agree with the statement ‘I am a narcissist.’”
# Additional categorical data includes the video game platform of choice, academic degree achieved, country of origin, and country of residence.
#
# A number of fill-in questions are provided that will need to be cleaned and categorized. These include which video game participants play most, why they play video games, play-style, money earned while playing, rating in any rating system in their game of choice, and highest rating if any in gaming.
#
#
# **References**
#
# Dataset:
# https://www.kaggle.com/datasets/divyansh22/online-gaming-anxiety-data/data
# Original Data Provenance:
# https://osf.io/vnbxk/
#
# GAD-7:
# https://www.phqscreeners.com/images/sites/g/files/g10060481/f/201412/GAD-7_English.pdf
# SPIN-17:
# KM Connor, et al. Psychometric Properties of the Social Phobia Inventory (SPIN): New Self-Rating Scale. British Journal Psych. 2000.
# SWL-5:
# https://fetzer.org/sites/default/files/images/stories/pdf/selfmeasures/SATISFACTION-SatisfactionWithLife.pdf
# SINS-1:
# https://dx.plos.org/10.1371/journal.pone.0103469

# %% [markdown]
# # Initial Data Exploration

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
os.chdir("../")

# %%
# %pwd

# %%
# ensure working directory is root of project
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
filepath = "python/data/gaming_anxiety.csv"
nas = ["", " ", "NA", "N/A", "na", "n/a"]
df = pd.read_csv(filepath, na_values=nas, encoding="ISO-8859-1")

# %%
print(df.shape)
df
# Out:
# (13464, 55)
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0           1  42052.00437     0     0     0     0     1     0     0
# 1           2  42052.00680     1     2     2     2     0     1     0
# 2           3  42052.03860     0     2     2     0     0     3     1
# 3           4  42052.06804     0     0     0     0     0     0     0
# 4           5  42052.08948     2     1     2     2     2     3     2
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13459   14246  42057.75678     1     0     0     1     0     1     1
# 13460   14247  42057.81185     3     3     3     3     2     3     3
# 13461   14248  42058.16964     0     0     0     0     0     0     0
# 13462   14249  42058.24420     3     2     1     3     0     1     3
# 13463   14250  42058.36375     1     1     0     0     0     0     0
#
#                        GADE  ...  Birthplace    Residence  Reference  \
# ...

# %%
print(df.columns)
df.iloc[:, 2:].describe()
# Out:
# Index(['S. No.', 'Timestamp', 'GAD1', 'GAD2', 'GAD3', 'GAD4', 'GAD5', 'GAD6',
#        'GAD7', 'GADE', 'SWL1', 'SWL2', 'SWL3', 'SWL4', 'SWL5', 'Game',
#        'Platform', 'Hours', 'earnings', 'whyplay', 'League', 'highestleague',
#        'streams', 'SPIN1', 'SPIN2', 'SPIN3', 'SPIN4', 'SPIN5', 'SPIN6',
#        'SPIN7', 'SPIN8', 'SPIN9', 'SPIN10', 'SPIN11', 'SPIN12', 'SPIN13',
#        'SPIN14', 'SPIN15', 'SPIN16', 'SPIN17', 'Narcissism', 'Gender', 'Age',
#        'Work', 'Degree', 'Birthplace', 'Residence', 'Reference', 'Playstyle',
#        'accept', 'GAD_T', 'SWL_T', 'SPIN_T', 'Residence_ISO3',
#        'Birthplace_ISO3'],
#       dtype='object')
#                GAD1          GAD2          GAD3          GAD4          GAD5  \
# count  13464.000000  13464.000000  13464.000000  13464.000000  13464.000000
# mean       0.860963      0.673351      0.965761      0.724079      0.488042
# std        0.926542      0.915724      0.982776      0.921971      0.837014
# ...

# %%
# select numeric columns
numeric_cols = df.select_dtypes(include="number").columns
numeric_cols = numeric_cols[2:]
numeric_cols
# Out:
# Index(['GAD1', 'GAD2', 'GAD3', 'GAD4', 'GAD5', 'GAD6', 'GAD7', 'SWL1', 'SWL2',
#        'SWL3', 'SWL4', 'SWL5', 'Hours', 'highestleague', 'streams', 'SPIN1',
#        'SPIN2', 'SPIN3', 'SPIN4', 'SPIN5', 'SPIN6', 'SPIN7', 'SPIN8', 'SPIN9',
#        'SPIN10', 'SPIN11', 'SPIN12', 'SPIN13', 'SPIN14', 'SPIN15', 'SPIN16',
#        'SPIN17', 'Narcissism', 'Age', 'GAD_T', 'SWL_T', 'SPIN_T'],
#       dtype='object')

# %%
# select categorical columns
cat_cols = df.select_dtypes(include="object").columns
cat_cols
# Out:
# Index(['GADE', 'Game', 'Platform', 'earnings', 'whyplay', 'League', 'Gender',
#        'Work', 'Degree', 'Birthplace', 'Residence', 'Reference', 'Playstyle',
#        'accept', 'Residence_ISO3', 'Birthplace_ISO3'],
#       dtype='object')

# %%
# check missing values
df.isna().sum().sort_values(ascending=False) / len(df)
# Out:
# highestleague      1.000000
# League             0.137998
# Degree             0.117127
# SPIN_T             0.048277
# GADE               0.048203
# accept             0.030749
# SPIN13             0.013889
# SPIN11             0.013889
# SPIN17             0.012998
# SPIN12             0.012478
# SPIN5              0.012329
# SPIN10             0.011884
# SPIN4              0.011809
# SPIN9              0.011735
# SPIN14             0.011586
# SPIN6              0.011586
# SPIN2              0.011438
# SPIN15             0.010918
# SPIN16             0.010918
# SPIN8              0.010695
# SPIN3              0.010398
# SPIN7              0.010250
# SPIN1              0.009210
# Birthplace_ISO3    0.008987
# Residence_ISO3     0.008170
# streams            0.007427
# Work               0.002822
# Hours              0.002228
# Narcissism         0.001708
# Reference          0.001114
# GAD1               0.000000
# SWL_T              0.000000
# GAD_T              0.000000
# ...

# %% [markdown]
# ## Creating Target Variables
#
# ### SPIN (Social Phobia Inventory)
#
# https://greenspacehealth.com/en-us/social-anxiety-spin/
# https://psychology-tools.com/test/spin
#
# For each statement below, please select the number that best describes how you have been feeling during the last week, on a scale from (0-4): :
# - I am afraid of people in authority
# - I am bothered by blushing in front of people
# - Parties and social events scare me
# - I avoid talking to people I don’t know
# - Being criticized scares me a lot
# - I avoid doing things or speaking to people for fear of embarrassment
# - Sweating in front of people causes me distress
# - I avoid going to parties
# - I avoid activities in which I am the center of attention
# - Talking to strangers scares me
# - I avoid having to give speeches
# - I would do anything to avoid being criticized
# - Heart palpitations bother me when I am around people
# - I am afraid of doing things when people might be watching
# - Being embarrassed or looking stupid are among my worst fears
# - I avoid speaking to anyone in authority
# - Trembling or shaking in front of others is distressing to me
#
# 0 = Not at all
# 1 = A little bit
# 2 = Somewhat
# 3 = Very Much
# 4 = Extremely
#
# Scoring: The total SPIN score is calculated by adding up all of the items.
# A score above 19 appears to suggest a possibility of social anxiety and in research distinguished between social phobia and a control group.
# The possible range is between 0 and 68.
#
#
#
# | Score  | Symptom Severity |
# |--------|-------------------|
# | 0 - 20 | None             |
# | 21 - 30 | Mild            |
# | 31 - 40 | Moderate        |
# | 41 - 50 | Severe          |
# | 51 - 68 | Very Severe     |

# %%
df.loc[:, ["GAD_T", "SWL_T", "SPIN_T"]].describe()
# Out:
#               GAD_T         SWL_T        SPIN_T
# count  13464.000000  13464.000000  12814.000000
# mean       5.211973     19.788844     19.848525
# std        4.713267      7.229243     13.467493
# min        0.000000      5.000000      0.000000
# 25%        2.000000     14.000000      9.000000
# 50%        4.000000     20.000000     17.000000
# 75%        8.000000     26.000000     28.000000
# max       21.000000     35.000000     68.000000

# %%
tmp = df.copy()
tmp["SPIN_T"].hist()
plt.title("SPIN Total Score")
# Out:
# Text(0.5, 1.0, 'SPIN Total Score')

# %%
# create a categorical variable for SPIN_T
tmp["social_phobia"] = tmp["SPIN_T"].apply(lambda x: "None" if x <= 20 else "Mild" if x <= 30 else "Moderate" if x <= 40 else "Severe" if x <= 50 else "Very Severe")

# create a binary variable for SPIN_T: "A score above 19 appears to suggest a possibility of social anxiety and in research distinguished between social phobia and a control group."
tmp["social_anxiety"] = tmp["SPIN_T"].apply(lambda x: 1 if x >=19 else 0)

# barplot of social anxiety and social anxiety binary side-by-side
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
tmp["social_phobia"].value_counts().plot(kind="bar", ax=ax[0])
ax[0].set_title("Social Phobia")
tmp["social_anxiety"].value_counts().plot(kind="bar", ax=ax[1])
ax[1].set_title("Social Anxiety (>=19)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### GAD-7 – Assessment tool for Generalized Anxiety Disorder
#
# - scores 7 common anxiety symptoms
# - for official scoring, total score
# https://www.phqscreeners.com/images/sites/g/files/g10060481/f/201412/GAD-7_English.pdf
# https://www.dartmouth-hitchcock.org/sites/default/files/2021-02/gad-7-anxiety-scale.pdf
#
# Over the last 2 weeks, how often have you been bothered by the following problems?
# - Feeling nervous, anxious or on edge
# - Not being able to stop or control worrying
# - Worrying too much about different things
# - Trouble relaxing
# - Being so restless that it is hard to sit still
# - Becoming easily annoyed or irritable
# - Feeling afraid as if something awful might happen
#
# Score: 0 = Not at all; 1 = Several Days; 2 = More than half the days; 3 = Nearly every day
#
# (GAD_E) If you checked off any problems, how difficult have these made it for you to do your work, take care of things at home, or get along with other people?
#
# Not difficult at all
# Somewhat difficult
# Very difficult
# Extremely difficult
#
# Scoring:
#
# | Score | Anxiety Severity   |
# |-------|--------------------|
# | 0 - 4 | None - Minimal     |
# | 5 - 9 | Mild               |
# | 10 - 14 | Moderate         |
# | 15 - 21 | Severe           |
#
# https://mantracare.org/therapy/anxiety/gad-7/#Scoring_The_GAD-7_Scale

# %%
tmp["GAD_T"].hist()
plt.title("GAD-7 Total Score")
# Out:
# Text(0.5, 1.0, 'GAD-7 Total Score')

# %%
# create a categorical variable for GAD_T
tmp["anxiety"] = tmp["GAD_T"].apply(lambda x: "None" if x <= 4 else "Mild" if x <= 9 else "Moderate" if x <= 14 else "Severe")

# create a binary variable for GAD__T: None and Mild = 0, Moderate and Severe = 1
tmp["anxiety_binary"] = tmp["GAD_T"].apply(lambda x: 0 if x <= 9 else 1)

# barplot of anxiety and anxiety binary side-by-side
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
tmp["anxiety"].value_counts().plot(kind="bar", ax=ax[0])
ax[0].set_title("GAD")
tmp["anxiety_binary"].value_counts().plot(kind="bar", ax=ax[1])
ax[1].set_title("GAD (>=10)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### SWL (Satisfaction With Life Scale - 5 question assessment)
#
# https://fetzer.org/sites/default/files/images/stories/pdf/selfmeasures/SATISFACTION-SatisfactionWithLife.pdf
# https://www.mdapp.co/satisfaction-with-life-swl-scale-calculator-367/
#
# Scale:
#
# Instructions: Below are five statements that you may agree or disagree with. Using the 1 -
# 7 scale below, indicate your agreement with each item by placing the appropriate number
# on the line preceding that item. Please be open and honest in your responding.
#
# • 7 - Strongly agree
# • 6 - Agree
# • 5 - Slightly agree
# • 4 - Neither agree nor disagree
# • 3 - Slightly disagree
# • 2 - Disagree
# • 1 - Strongly disagree
# ____ In most ways my life is close to my ideal. (Q1)
# ____ The conditions of my life are excellent. (Q2)
# ____ I am satisfied with my life. (Q3)
# ____ So far I have gotten the important things I want in life. (Q4)
# ____ If I could live my life over, I would change almost nothing. (Q5)
#
# Scoring:
# Though scoring should be kept continuous (sum up scores on each item), here are some cutoffs to be used as benchmarks.
#
# | Score | Interpretation         |
# |-------|------------------------|
# | 31 - 35 | Extremely Satisfied  |
# | 26 - 30 | Satisfied            |
# | 21 - 25 | Slightly Satisfied   |
# | 20      | Neutral              |
# | 15 - 19 | Slightly Dissatisfied|
# | 10 - 14 | Dissatisfied         |
# | 5 - 9   | Extremely Dissatisfied|

# %%
tmp["SWL_T"].hist()
plt.title("SWL Total Score")
# Out:
# Text(0.5, 1.0, 'SWL Total Score')

# %%
# create a categorical variable for SWL_T
tmp["life_satisfaction"] = tmp["SWL_T"].apply(lambda x: "Extremely Satisfied" if x >= 31 else "Satisfied" if x >= 26 else "Slightly Satisfied" if x >= 21 else "Neutral" if x >= 20 else "Slightly Dissatisfied" if x >= 15 else "Dissatisfied" if x >= 10 else "Extremely Dissatisfied")

# barplot of life satisfaction
tmp["life_satisfaction"].value_counts().plot(kind="bar")
plt.title("Life Satisfaction")
# Out:
# Text(0.5, 1.0, 'Life Satisfaction')

# %% [markdown]
# ### Combined Target Variable - Moderate/Severe SPIN/GAD

# %%
# create combined target variable: if a person has social anxiety or anxiety (binary) then 1, else 0
tmp["combined_target"] = tmp["social_anxiety"] + tmp["anxiety_binary"]
tmp["combined_target"] = tmp["combined_target"].apply(lambda x: 1 if x >= 1 else 0)

# barplot of combined target variable
tmp["combined_target"].value_counts().plot(kind="bar")
plt.title("Moderate/Severe SPIN/GAD")
# Out:
# Text(0.5, 1.0, 'Moderate/Severe SPIN/GAD')

# %%
# check correlation between SWL_T and SPIN_T
tmp[["SWL_T", "SPIN_T"]].corr()

# check correlation between SWL_T and GAD_T
tmp[["SWL_T", "GAD_T"]].corr()

# check correlation between SPIN_T and GAD_T
tmp[["SPIN_T", "GAD_T"]].corr()
# Out:
#           SPIN_T     GAD_T
# SPIN_T  1.000000  0.454654
# GAD_T   0.454654  1.000000

# %%
# check potential features that could predict whether a person has severe SPIN/GAD (combined target variable)
tmp2 = tmp.copy()

# drop columns that GAD1:GAD7 (excluding GADE), SWL1:SWL5, SPIN1:SPIN17
tmp2.drop(tmp2.columns[0:9], axis=1, inplace=True)
tmp2.drop(tmp2.columns[1:6], axis=1, inplace=True)
tmp2.drop(tmp2.columns[9:26], axis=1, inplace=True)

# drop highestleague
tmp2.drop("highestleague", axis=1, inplace=True)
numeric_cols = tmp2.select_dtypes(include="number").columns
cat_cols = tmp2.select_dtypes(include="object").columns
print(numeric_cols)
print(cat_cols)
# Out:
# Index(['Hours', 'streams', 'Narcissism', 'Age', 'GAD_T', 'SWL_T', 'SPIN_T',
#        'social_anxiety', 'anxiety_binary', 'combined_target'],
#       dtype='object')
# Index(['GADE', 'Game', 'Platform', 'earnings', 'whyplay', 'League', 'Gender',
#        'Work', 'Degree', 'Birthplace', 'Residence', 'Reference', 'Playstyle',
#        'accept', 'Residence_ISO3', 'Birthplace_ISO3', 'social_phobia',
#        'anxiety', 'life_satisfaction'],
#       dtype='object')

# %%
""" # check potential features that could predict whether a person has severe SPIN/GAD (combined target variable)
tmp2 = tmp.copy()
# drop columns that GAD1:GAD7, SWL1:SWL5, SPIN1:SPIN17
tmp2.drop(tmp2.columns[0:15], axis=1, inplace=True)
tmp2.drop(tmp2.columns[8:25], axis=1, inplace=True)
# drop highstleague
tmp2.drop("highestleague", axis=1, inplace=True)
numeric_cols = tmp2.select_dtypes(include="number").columns
cat_cols = tmp2.select_dtypes(include="object").columns
print(numeric_cols)
print(cat_cols) """
# Out:
# ' # check potential features that could predict whether a person has severe SPIN/GAD (combined target variable)\ntmp2 = tmp.copy()\n# drop columns that GAD1:GAD7, SWL1:SWL5, SPIN1:SPIN17\ntmp2.drop(tmp2.columns[0:15], axis=1, inplace=True)\ntmp2.drop(tmp2.columns[8:25], axis=1, inplace=True)\n# drop highstleague\ntmp2.drop("highestleague", axis=1, inplace=True)\nnumeric_cols = tmp2.select_dtypes(include="number").columns\ncat_cols = tmp2.select_dtypes(include="object").columns\nprint(numeric_cols)\nprint(cat_cols) '

# %%
import seaborn as sns
sns.heatmap(tmp2[numeric_cols].corr(), annot=False, cmap="Blues")
plt.show()

# %%
# age hist
tmp2["Age"].hist()
# Out:
# <Axes: >

# %%
# earnings
tmp2["earnings"].value_counts()
# Out:
# earnings
# I play for fun                                                                               12112
# I play mostly for fun but earn a little on the side (tournament winnings, streaming, etc)      990
# I earn a living by playing this game                                                            48
# I play to win                                                                                    3
# i try                                                                                            2
#                                                                                              ...
# I play for fun, but if there's an opportunity to earn some money, I would love to.               1
# Keep in touch w/ friends                                                                         1
# I Play for fun and working on making earn out of it.                                             1
# ...

# %%
# work
tmp2["Degree"].value_counts()
# Out:
# Degree
# High school diploma (or equivalent)    8560
# Bachelor (or equivalent)               2687
# Master (or equivalent)                  546
# Ph.D., Psy. D., MD (or equivalent)       94
# Name: count, dtype: int64

# %%
# 2 side-by side barcharts of Degree and Work by combined target
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
tmp2.groupby("Degree")["combined_target"].value_counts().unstack().plot(kind="bar", ax=ax[0])
ax[0].set_title("Degree")
# set legend title
ax[0].legend(title="Severe SPIN/GAD")
tmp2.groupby("Work")["combined_target"].value_counts().unstack().plot(kind="bar", ax=ax[1])
ax[1].set_title("Work")
ax[1].legend(title="Severe SPIN/GAD")

plt.tight_layout()

plt.show()

# %%
# 2 side-by side barcharts of whyplay and Birthplace by combined target
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
tmp2.groupby("Platform")["combined_target"].value_counts().unstack().plot(kind="bar", ax=ax[0])
ax[0].set_title("Platform")
# set legend title
ax[0].legend(title="Severe SPIN/GAD")
tmp2.groupby("Gender")["combined_target"].value_counts().unstack().plot(kind="bar", ax=ax[1])
ax[1].set_title("Gender")
ax[1].legend(title="Severe SPIN/GAD")
plt.show()

# %% [markdown]
# # Potential Modeling Directions
#
# - We plan to use the binary Social Anxiety variable as our target variable with the aim to develop a classifier that can
#  predict whether a person has social anxiety or not.
#
# - We could also use the Social Phobia variable as our target variable with the aim to develop a classifier that can
# predict the level of social anxiety a person has. This would be a multi-class classification problem and based on the
# distribution, we may experience the class imbalance problem.
#
# - Similarly, we could use the binary Anxiety variable as our target variable with the aim to develop a classifier
# that can predict whether a person has anxiety or not. We could create a new combined target variable that is a
# combination of the Social Anxiety and Anxiety variables. For example, if a person has social anxiety or anxiety
# (binary). Such classifier could be used to predict if a person is likely to have a Moderate/Severe SPIN/GAD.
#
# - From the first glance, potential features that could predict whether a person has moderate/severe SPIN/GAD are work,
# earnings, life satisfaction. We will explore these features further to see if they are good predictors.
#
#
# ## Classification Models
#
# ### Baseline Model
#
# - We will use the logistic regression model as our baseline model, keeping in mind to start with the simplest model
# and set of features.
#
# ### Decision Tree/Random Forest
#
# - We will use the decision tree and random forest models to see if we can improve the performance of the baseline
# model. Decision trees can capture non-linear relationships in the data, and random forests can reduce
# potential overfitting and improve generalization.
#
# ### Naive Bayes or SVM
#
# - For our third model, we will use either the Naive Bayes or SVM model to compare the performance to predict whether
# gamers are likely to have severe social anxiety or not.

# %%
df = tmp2.copy()
df
# Out:
#                        GADE               Game                 Platform  \
# 0      Not difficult at all             Skyrim  Console (PS, Xbox, ...)
# 1        Somewhat difficult              Other                       PC
# 2      Not difficult at all              Other                       PC
# 3      Not difficult at all              Other                       PC
# 4            Very difficult              Other  Console (PS, Xbox, ...)
# ...                     ...                ...                      ...
# 13459  Not difficult at all              Other  Console (PS, Xbox, ...)
# 13460   Extremely difficult  League of Legends                       PC
# 13461  Not difficult at all        Starcraft 2                       PC
# 13462    Somewhat difficult              Other  Console (PS, Xbox, ...)
# 13463    Somewhat difficult        Starcraft 2                       PC
#
#        Hours        earnings     whyplay   League  streams  Narcissism  \
# ...

# %%
# check for all missing values
df.isna().sum()[0:29]
# Out:
# GADE                  649
# Game                    0
# Platform                0
# Hours                  30
# earnings                0
# whyplay                 0
# League               1858
# streams               100
# Narcissism             23
# Gender                  0
# Age                     0
# Work                   38
# Degree               1577
# Birthplace              0
# Residence               0
# Reference              15
# Playstyle               0
# accept                414
# GAD_T                   0
# SWL_T                   0
# SPIN_T                650
# Residence_ISO3        110
# Birthplace_ISO3       121
# social_phobia           0
# social_anxiety          0
# anxiety                 0
# anxiety_binary          0
# life_satisfaction       0
# combined_target         0
# dtype: int64

# %%
# remove rows with missing values
df = df.dropna(subset=['GADE', 'Hours', 'League', 'streams', 
                       'Narcissism', 'Work', 'Degree', 'Reference', 
                       'accept', 'SPIN_T', 'Residence_ISO3', 'Birthplace_ISO3'])

# %%
# confirm cleaned missing values
df.isna().sum()[0:29]
# Out:
# GADE                 0
# Game                 0
# Platform             0
# Hours                0
# earnings             0
# whyplay              0
# League               0
# streams              0
# Narcissism           0
# Gender               0
# Age                  0
# Work                 0
# Degree               0
# Birthplace           0
# Residence            0
# Reference            0
# Playstyle            0
# accept               0
# GAD_T                0
# SWL_T                0
# SPIN_T               0
# Residence_ISO3       0
# Birthplace_ISO3      0
# social_phobia        0
# social_anxiety       0
# anxiety              0
# anxiety_binary       0
# life_satisfaction    0
# combined_target      0
# dtype: int64

# %%
# reindex (NOW HAS 8740 ROWS)
df = df.reset_index(drop=True)

# %%
# select numeric columns
numeric_columns = df.select_dtypes(include="number").columns
numeric_columns
# Out:
# Index(['Hours', 'streams', 'Narcissism', 'Age', 'GAD_T', 'SWL_T', 'SPIN_T',
#        'social_anxiety', 'anxiety_binary', 'combined_target'],
#       dtype='object')

# %%
# select categorical columns
cat_columns = df.select_dtypes(include="object").columns
cat_columns
# Out:
# Index(['GADE', 'Game', 'Platform', 'earnings', 'whyplay', 'League', 'Gender',
#        'Work', 'Degree', 'Birthplace', 'Residence', 'Reference', 'Playstyle',
#        'accept', 'Residence_ISO3', 'Birthplace_ISO3', 'social_phobia',
#        'anxiety', 'life_satisfaction'],
#       dtype='object')

# %% [markdown]
# # Feature Scaling/Transformation?

# %%
""" from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

num_columns_ls = list(numeric_columns)
cat_columns_ls = list(cat_columns)

# removing features
num_columns_ls.remove('social_anxiety')
num_columns_ls.remove('anxiety_binary')
num_columns_ls.remove('combined_target')
#num_columns_ls.remove('SPIN_T')
#num_columns_ls.remove('GAD_T')
#num_columns_ls.remove('SWL_T')

numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, num_columns_ls),
        ('cat', categorical_transformer, cat_columns_ls)
])

df_processed = preprocessor.fit_transform(df) """
# Out:
# " from sklearn.preprocessing import OneHotEncoder, StandardScaler\nfrom sklearn.compose import ColumnTransformer\nfrom sklearn.pipeline import Pipeline\nfrom sklearn.impute import SimpleImputer\n\nnum_columns_ls = list(numeric_columns)\ncat_columns_ls = list(cat_columns)\n\n# removing features\nnum_columns_ls.remove('social_anxiety')\nnum_columns_ls.remove('anxiety_binary')\nnum_columns_ls.remove('combined_target')\n#num_columns_ls.remove('SPIN_T')\n#num_columns_ls.remove('GAD_T')\n#num_columns_ls.remove('SWL_T')\n\nnumerical_transformer = Pipeline(steps=[\n    ('imputer', SimpleImputer(strategy='median')),\n    ('scaler', StandardScaler())\n])\n\ncategorical_transformer = Pipeline(steps=[\n    ('imputer', SimpleImputer(strategy='most_frequent')),\n    ('onehot', OneHotEncoder(handle_unknown='ignore'))\n])\n\npreprocessor = ColumnTransformer(\n    transformers=[\n        ('num', numerical_transformer, num_columns_ls),\n        ('cat', categorical_transformer, cat_columns_ls)\n])\n\nd
# ...

# %% [markdown]
# # Feature Selection

# %%
# target variables
y = df['social_anxiety']
y2 = df['anxiety_binary']
y3 = df['combined_target']

# %%
drop_columns = ['GAD_T', 'SWL_T', 'SPIN_T', 'social_anxiety', 
                'anxiety_binary', 'combined_target', 'anxiety', 'social_phobia']

# turn cat_columns into list
cat_columns_ls = list(cat_columns)
cat_columns_ls.remove('anxiety')
cat_columns_ls.remove('social_phobia')

# %% [markdown]
# ### Social Anxiety

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# Split the data into features and target
# X is numeric_columns combined with cat_columns and cat_columns must all be one-hot encoded
column_transformer = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(), cat_columns_ls)
    ],
    remainder='passthrough',
    sparse_threshold=0  # ensures the output is a dense matrix
)
# X variable needs to contain both numeric and categorical features
X = column_transformer.fit_transform(df.drop(drop_columns, axis=1))

# Select the top 30 features
selector = SelectKBest(f_classif, k=30)
selector.fit(X, y) # target: social_anxiety

feature_names_transformed = column_transformer.get_feature_names_out()

# Get the indices of the selected features
selected_features = selector.get_support(indices=True)

# Get the selected feature names
selected_feature_names = feature_names_transformed[selected_features]
print(selected_feature_names)
# Out:
# ['cat__GADE_Extremely difficult' 'cat__GADE_Not difficult at all'
#  'cat__GADE_Somewhat difficult' 'cat__GADE_Very difficult'
#  'cat__earnings_I play mostly for fun but earn a little on the side (tournament winnings, streaming, etc)'
#  'cat__whyplay_having fun' 'cat__whyplay_winning' 'cat__Gender_Female'
#  'cat__Gender_Male' 'cat__Work_Employed'
#  'cat__Work_Unemployed / between jobs'
#  'cat__Degree_Bachelor\xa0(or equivalent)'
#  'cat__Degree_High school diploma (or equivalent)'
#  'cat__Degree_Master\xa0(or equivalent)'
#  'cat__Degree_Ph.D., Psy. D., MD (or equivalent)'
#  'cat__Birthplace_Denmark' 'cat__Birthplace_UK' 'cat__Residence_UK'
#  'cat__Playstyle_Singleplayer' 'cat__Residence_ISO3_GBR'
#  'cat__Birthplace_ISO3_DNK' 'cat__Birthplace_ISO3_GBR'
#  'cat__life_satisfaction_Dissatisfied'
#  'cat__life_satisfaction_Extremely Dissatisfied'
#  'cat__life_satisfaction_Extremely Satisfied'
#  'cat__life_satisfaction_Satisfied'
# ...

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# Split the data into features and target
# X is numeric_columns combined with cat_columns and cat_columns must all be one-hot encoded
column_transformer = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(), cat_columns_ls)
    ],
    remainder='passthrough',
    sparse_threshold=0  # ensures the output is a dense matrix
)
# X variable needs to contain both numeric and categorical features
X = column_transformer.fit_transform(df.drop(drop_columns, axis=1))

# Select the top 30 features
selector = SelectKBest(f_classif, k=30)
selector.fit(X, y) # target: social_anxiety

feature_names_transformed = column_transformer.get_feature_names_out()

# Get the indices of the selected features
selected_features = selector.get_support(indices=True)

# Get the selected feature names
selected_feature_names = feature_names_transformed[selected_features]
print(selected_feature_names)
# Out:
# ['cat__GADE_Extremely difficult' 'cat__GADE_Not difficult at all'
#  'cat__GADE_Somewhat difficult' 'cat__GADE_Very difficult'
#  'cat__earnings_I play mostly for fun but earn a little on the side (tournament winnings, streaming, etc)'
#  'cat__whyplay_having fun' 'cat__whyplay_winning' 'cat__Gender_Female'
#  'cat__Gender_Male' 'cat__Work_Employed'
#  'cat__Work_Unemployed / between jobs'
#  'cat__Degree_Bachelor\xa0(or equivalent)'
#  'cat__Degree_High school diploma (or equivalent)'
#  'cat__Degree_Master\xa0(or equivalent)'
#  'cat__Degree_Ph.D., Psy. D., MD (or equivalent)'
#  'cat__Birthplace_Denmark' 'cat__Birthplace_UK' 'cat__Residence_UK'
#  'cat__Playstyle_Singleplayer' 'cat__Residence_ISO3_GBR'
#  'cat__Birthplace_ISO3_DNK' 'cat__Birthplace_ISO3_GBR'
#  'cat__life_satisfaction_Dissatisfied'
#  'cat__life_satisfaction_Extremely Dissatisfied'
#  'cat__life_satisfaction_Extremely Satisfied'
#  'cat__life_satisfaction_Satisfied'
# ...

# %% [markdown]
# ### Generalized Anxiety

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# Split the data into features and target
# X is numeric_columns combined with cat_columns and cat_columns must all be one-hot encoded
column_transformer = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(), cat_columns_ls)
    ],
    remainder='passthrough',
    sparse_threshold=0  # ensures the output is a dense matrix
)
# X variable needs to contain both numeric and categorical features
X = column_transformer.fit_transform(df.drop(drop_columns, axis=1))

# Select the top 30 features
selector = SelectKBest(f_classif, k=30)
selector.fit(X, y2) # target: anxiety_binary

feature_names_transformed = column_transformer.get_feature_names_out()

# Get the indices of the selected features
selected_features = selector.get_support(indices=True)

# Get the selected feature names
selected_feature_names = feature_names_transformed[selected_features]
print(selected_feature_names)
# Out:
# ['cat__GADE_Extremely difficult' 'cat__GADE_Not difficult at all'
#  'cat__GADE_Somewhat difficult' 'cat__GADE_Very difficult'
#  'cat__whyplay_having fun' 'cat__whyplay_relaxing' 'cat__whyplay_winning'
#  'cat__League_Bronze V' 'cat__Gender_Female' 'cat__Gender_Male'
#  'cat__Gender_Other' 'cat__Work_Employed'
#  'cat__Work_Unemployed / between jobs'
#  'cat__Degree_High school diploma (or equivalent)'
#  'cat__Birthplace_Germany' 'cat__Residence_Egypt' 'cat__Residence_UK'
#  'cat__Playstyle_Multiplayer - online - with real life friends'
#  'cat__Playstyle_Multiplayer - online - with strangers'
#  'cat__Residence_ISO3_EGY' 'cat__Residence_ISO3_GBR'
#  'cat__Birthplace_ISO3_DEU' 'cat__life_satisfaction_Dissatisfied'
#  'cat__life_satisfaction_Extremely Dissatisfied'
#  'cat__life_satisfaction_Extremely Satisfied'
#  'cat__life_satisfaction_Satisfied'
#  'cat__life_satisfaction_Slightly Satisfied' 'remainder__Hours'
#  'remainder__streams' 'remainder__Narcissism']
# ...

# %% [markdown]
# ### Combined Anxieties (one or the other)

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# Split the data into features and target
# X is numeric_columns combined with cat_columns and cat_columns must all be one-hot encoded
column_transformer = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(), cat_columns_ls)
    ],
    remainder='passthrough',
    sparse_threshold=0  # ensures the output is a dense matrix
)
# X variable needs to contain both numeric and categorical features
X = column_transformer.fit_transform(df.drop(drop_columns, axis=1))

# Select the top 50 features
selector = SelectKBest(f_classif, k=50)
selector.fit(X, y3) # target: combined_target

feature_names_transformed = column_transformer.get_feature_names_out()

# Get the indices of the selected features
selected_features = selector.get_support(indices=True)

# Get the selected feature names
selected_feature_names = feature_names_transformed[selected_features]
print(selected_feature_names)
# Out:
# c:\Users\gaiag\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [2036] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# ['cat__GADE_Extremely difficult' 'cat__GADE_Not difficult at all'
#  'cat__GADE_Somewhat difficult' 'cat__GADE_Very difficult'
#  'cat__Game_Starcraft 2'
#  'cat__earnings_I play mostly for fun but earn a little on the side (tournament winnings, streaming, etc)'
#  'cat__whyplay_having fun' 'cat__whyplay_winning' 'cat__League_Bronze V'
#  'cat__League_Unranked' 'cat__League_platinum 2' 'cat__Gender_Female'
#  'cat__Gender_Male' 'cat__Gender_Other' 'cat__Work_Employed'
#  'cat__Work_Unemployed / between jobs'
#  'cat__Degree_Bachelor\xa0(or equivalent)'
#  'cat__Degree_High school diploma (or equivalent)'
#  'cat__Degree_Master\xa0(or equivalent)'
#  'cat__Degree_Ph.D., Psy. D., MD (or equivalent)' 'cat__Birthplace_Brazil'
# ...

# %% [markdown]
# #### Discussion & Feature Selection Warnings
# - Based on the (k=50) SelectKBest feature selection (with 'combined_target' as the target variable) and the (k=30) SelectKBest feature selection (with 'social_anxiety' and also 'anxiety_binary', as two separate target variables), it seems as if these columns could also be of interest/influence towards gamers' anxiety:
#     - earnings, Work, life_satisfaction (initially included)
#     - GADE, Game, whyplay, League, Gender, Degree,
#     - Birthplace, Residence, Playstyle, social_phobia, anxiety
# - Warnings:
#     - Constant Features: Some features have constant values (i.e., they do not change) across all samples in the dataset. Features that are constant cannot be used to discriminate between classes or predict a target variable because they do not provide any information that can help in making a distinction.
#     - Second warning is about having invalid values in division when computing statistics for feature selection--this can happen if a feature has a very low variance (close to zero), leading to instability in calculations like the F statistic.

# %% [markdown]
# ### PCA

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# pca
pca = PCA(n_components=5)
principalComponents = pca.fit_transform(X_scaled)

# df for plotting
pca_df = pd.DataFrame(data=principalComponents, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5'])
pca_df['social_anxiety'] = y

# Define figure and 3D axis
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot using first three principal components
scatter = ax.scatter(pca_df['PC1'], pca_df['PC2'], pca_df['PC3'], 
                     c=pca_df['PC4'], s=pca_df['PC5']*100,  # Color by PC4, Size by PC5
                     cmap='viridis', alpha=0.6, edgecolors='w')

# color bar and labels
cbar = plt.colorbar(scatter, ax=ax)
cbar.set_label('Principal Component 4')

ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')

plt.title('3D Scatter Plot of First Three Principal Components')
plt.show()
print("Explained variance ratio:", pca.explained_variance_ratio_)
# Out:
# c:\Users\gaiag\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# Explained variance ratio: [0.00241592 0.00205067 0.00201501 0.00196892 0.00194056]

# %%
import numpy as np

pca_full = PCA()
pca_full.fit(X)

n_display_components = 100 

plt.figure(figsize=(8, 6))
plt.plot(np.cumsum(pca_full.explained_variance_ratio_)[:n_display_components])
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance by PCA Components')
plt.grid(True)

plt.xlim(0, n_display_components)
plt.xticks(np.arange(0, n_display_components, step=5)) 

elbow_point = 10 
plt.axvline(x=elbow_point, color='red', linestyle='--')

plt.show()

# %% [markdown]
# #### PCA Discussion
#     - Based on using the elbow method, we can see how at 2 principal components, the cumulative explained variance is at roughly 97%, and slowly rises--suggesting that a far greater number of features may be influential in determining the social_anxiety target variable than just 2.

# %% [markdown]
# # Model Pipeline

# %% [markdown]
# ## Social Anxiety

# %%
print(numeric_columns)
print(cat_columns)
# Out:
# Index(['Hours', 'streams', 'Narcissism', 'Age', 'GAD_T', 'SWL_T', 'SPIN_T',
#        'social_anxiety', 'anxiety_binary', 'combined_target'],
#       dtype='object')
# Index(['GADE', 'Game', 'Platform', 'earnings', 'whyplay', 'League', 'Gender',
#        'Work', 'Degree', 'Birthplace', 'Residence', 'Reference', 'Playstyle',
#        'accept', 'Residence_ISO3', 'Birthplace_ISO3', 'social_phobia',
#        'anxiety', 'life_satisfaction'],
#       dtype='object')

# %%
# columns of interest: change columns based on motivation/goals and run pipeline
columns_of_interest = ["Work", "earnings", "life_satisfaction"]

features = df[columns_of_interest]

y = df['social_anxiety']
y2 = df['anxiety_binary']
y3 = df['combined_target']

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# one hot encoding for categorical features
#cat_features_encoded = pd.get_dummies(df[columns_of_interest])
column_transformer = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(), columns_of_interest)
    ],
    remainder='passthrough',
    sparse_threshold=0  # ensures the output is a dense matrix
)

# Applying the transformation to the features
features_encoded = column_transformer.fit_transform(features)

# X and y
#X = pd.concat([df[numeric_columns], cat_features_encoded], axis=1)
#y = df['social_anxiety']

# splitting into training and test set --> stratify or not?
X_train, X_test, y_train, y_test = train_test_split(features_encoded, y, test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((6992, 215), (1748, 215), (6992,), (1748,))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

log_reg = LogisticRegression(max_iter=1000)  
log_reg.fit(X_train, y_train)

# predictions & evaluation
y_pred = log_reg.predict(X_test)
print(classification_report(y_test, y_pred, digits=4))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.6472    0.6479    0.6476       960
#            1     0.5705    0.5698    0.5702       788
#
#     accuracy                         0.6127      1748
#    macro avg     0.6089    0.6089    0.6089      1748
# weighted avg     0.6127    0.6127    0.6127      1748
#
# [[622 338]
#  [339 449]]

# %% [markdown]
# #### Parameter Tuning (GridSearchCV)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# Parameter grid for Logistic Regression
param_grid_lr = {
    'C': [0.01, 0.1, 1, 10, 100],  # Regularization parameter
    'penalty': ['l1', 'l2'],  # Norm of penalty
    'solver': ['liblinear']  # Solver compatible with l1 penalty
}

# GridSearchCV for Logistic Regression
grid_search_lr = GridSearchCV(estimator=LogisticRegression(random_state=42), 
                              param_grid=param_grid_lr, 
                              cv=5, scoring='roc_auc', n_jobs=-1)
grid_search_lr.fit(X_train, y_train)

print("Logistic Regression - Best Parameters:", grid_search_lr.best_params_)
print("Logistic Regression - Best AUC score:", grid_search_lr.best_score_)
# Out:
# Logistic Regression - Best Parameters: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# Logistic Regression - Best AUC score: 0.6603917362551555

# %%
# Using Best Parameters from GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, precision_score

best_params_lr = grid_search_lr.best_params_
log_reg = LogisticRegression(random_state=42, **best_params_lr)
log_reg.fit(X_train, y_train)
y_pred_lr = log_reg.predict(X_test)

auc_lr_SA = roc_auc_score(y_test, y_pred_lr)
precision_lr_SA = precision_score(y_test, y_pred_lr)

print(f"Logistic Regression AUC: {auc_lr_SA:.3f}")
print(f"Logistic Regression Precision: {precision_lr_SA:.3f}")
# Out:
# Logistic Regression AUC: 0.608
# Logistic Regression Precision: 0.569

# %%
# Assuming log_reg is the trained LogisticRegression model and X_train is a standardized dataset
importance_lr = log_reg.coef_[0]

# For interpretability, put them in a DataFrame
feature_names_lr = column_transformer.get_feature_names_out()
importance_lr_df = pd.DataFrame({'feature': feature_names_lr, 'importance': importance_lr}).sort_values('importance', ascending=False)

# Now visualize the feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='importance', y='feature', data=importance_lr_df.head(10))
plt.title('Logistic Regression Feature Importances')
plt.xlabel('Coefficient Value')
plt.ylabel('Feature')
plt.show()

# %%
import shap
# the magnitude of a SHAP value indicates the impact of a feature, and the sign indicates the direction of the impact (positive or negative).
explainer_lr = shap.LinearExplainer(log_reg, X_train)
shap_values_lr = explainer_lr.shap_values(X_train)
shap.summary_plot(shap_values_lr, X_train, feature_names=feature_names_lr)
# Out:
# Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.

# %% [markdown]
# ### Decision Tree/Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)
print(classification_report(y_test, rf_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.6493    0.6500    0.6497       960
#            1     0.5731    0.5723    0.5727       788
#
#     accuracy                         0.6150      1748
#    macro avg     0.6112    0.6112    0.6112      1748
# weighted avg     0.6149    0.6150    0.6150      1748

# %% [markdown]
# #### Parameter Tuning (GridSearchCV)

# %%
from sklearn.model_selection import GridSearchCV

# Parameter grid for Random Forest
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'class_weight': [None, 'balanced']
}

# gridsearchcv
rf = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, scoring='roc_auc', n_jobs=-1)

grid_search.fit(X_train, y_train)

print("Best parameters:", grid_search.best_params_)
print("Best AUC score:", grid_search.best_score_)
# Out:
# Best parameters: {'class_weight': 'balanced', 'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 300}
# Best AUC score: 0.6566366943280911

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, precision_score

# Training with best parameters from grid search
best_params_rf = grid_search.best_params_
rf = RandomForestClassifier(random_state=42, **best_params_rf)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

auc_rf_SA = roc_auc_score(y_test, y_pred_rf)
precision_rf_SA = precision_score(y_test, y_pred_rf)

print(f"Random Forest AUC: {auc_rf_SA:.3f}")
print(f"Random Forest Precision: {precision_rf_SA:.3f}")
# Out:
# Random Forest AUC: 0.607
# Random Forest Precision: 0.557

# %%
# Assuming rf is the trained RandomForestClassifier
importances = rf.feature_importances_

# To make the importances more interpretable, put them in a DataFrame
feature_names = column_transformer.get_feature_names_out()
importances_df = pd.DataFrame({'feature': feature_names, 'importance': importances}).sort_values('importance', ascending=False)

# Now you can visualize the feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='importance', y='feature', data=importances_df.head(10))
plt.title('Top 10 Feature Importances')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
nb_pred = nb_model.predict(X_test)
print(classification_report(y_test, nb_pred, digits=4, zero_division=1)) # UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# Out:
#               precision    recall  f1-score   support
#
#            0     0.5492    1.0000    0.7090       960
#            1     1.0000    0.0000    0.0000       788
#
#     accuracy                         0.5492      1748
#    macro avg     0.7746    0.5000    0.3545      1748
# weighted avg     0.7524    0.5492    0.3894      1748

# %% [markdown]
# #### Parameter Tuning (GridSearchCV)

# %%
from sklearn.naive_bayes import GaussianNB

# There typically aren't hyperparameters to tune for GaussianNB,
param_grid_nb = {
    'var_smoothing': [1e-9, 1e-8, 1e-7]  # Variance smoothing parameter
}

# GridSearchCV for Naive Bayes
grid_search_nb = GridSearchCV(estimator=GaussianNB(), 
                              param_grid=param_grid_nb, 
                              cv=5, scoring='roc_auc', n_jobs=-1)
grid_search_nb.fit(X_train, y_train)

print("Naive Bayes - Best Parameters:", grid_search_nb.best_params_)
print("Naive Bayes - Best AUC score:", grid_search_nb.best_score_)
# Out:
# Naive Bayes - Best Parameters: {'var_smoothing': 1e-09}
# Naive Bayes - Best AUC score: 0.6506246730498959

# %%
# Using Best Parameters from GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score, precision_score

best_params_nb = grid_search_nb.best_params_
naive_bayes = GaussianNB(**best_params_nb)
naive_bayes.fit(X_train, y_train)
y_pred_nb = naive_bayes.predict(X_test)

auc_nb_SA = roc_auc_score(y_test, y_pred_nb)
precision_nb_SA = precision_score(y_test, y_pred_nb)

print(f"Naive Bayes AUC: {auc_nb_SA:.3f}")
print(f"Naive Bayes Precision: {precision_nb_SA:.3f}")
# Out:
# Naive Bayes AUC: 0.500
# Naive Bayes Precision: 0.000
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC
svm_model = SVC()
svm_model.fit(X_train, y_train)
svm_pred = svm_model.predict(X_test)
print(classification_report(y_test, svm_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.6482    0.6448    0.6465       960
#            1     0.5700    0.5736    0.5718       788
#
#     accuracy                         0.6127      1748
#    macro avg     0.6091    0.6092    0.6091      1748
# weighted avg     0.6129    0.6127    0.6128      1748

# %% [markdown]
# #### Parameter Tuning (GridSearchCV)

# %%
from sklearn.svm import SVC

# Parameter grid for SVM
param_grid_svm = {
    'C': [0.1, 1, 10],  # Regularization parameter
    'gamma': ['scale', 'auto'],  # Kernel coefficient
    'kernel': ['rbf', 'linear']  # Specifies the kernel type to be used
}

# GridSearchCV for SVM
grid_search_svm = GridSearchCV(estimator=SVC(random_state=42), 
                               param_grid=param_grid_svm, 
                               cv=5, scoring='roc_auc', n_jobs=-1)
grid_search_svm.fit(X_train, y_train)

print("SVM - Best Parameters:", grid_search_svm.best_params_)
print("SVM - Best AUC score:", grid_search_svm.best_score_)
# Out:
# SVM - Best Parameters: {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# SVM - Best AUC score: 0.644587834147209

# %%
# Using Best Parameters from GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score, precision_score

best_params_svm = grid_search_svm.best_params_
svm = SVC(random_state=42, **best_params_svm)
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test)

auc_svm_SA = roc_auc_score(y_test, y_pred_svm)
precision_svm_SA = precision_score(y_test, y_pred_svm)

print(f"SVM AUC: {auc_svm_SA:.3f}")
print(f"SVM Precision: {precision_svm_SA:.3f}")
# Out:
# SVM AUC: 0.586
# SVM Precision: 0.612

# %% [markdown]
# ## Generalized Anxiety

# %% [markdown]
# ### Logistic Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(features_encoded, y2, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

log_reg = LogisticRegression(max_iter=1000)  
log_reg.fit(X_train, y_train)

# predictions & evaluation
y_pred = log_reg.predict(X_test)
print(classification_report(y_test, y_pred, digits=4))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8384    0.9959    0.9104      1464
#            1     0.3333    0.0106    0.0205       284
#
#     accuracy                         0.8358      1748
#    macro avg     0.5859    0.5032    0.4654      1748
# weighted avg     0.7564    0.8358    0.7658      1748
#
# [[1458    6]
#  [ 281    3]]

# %% [markdown]
# #### Parameter Tuning (GridSearchCV)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# Parameter grid for Logistic Regression
param_grid_lr = {
    'C': [0.01, 0.1, 1, 10, 100],  # Regularization parameter
    'penalty': ['l1', 'l2'],  # Norm of penalty
    'solver': ['liblinear']  # Solver compatible with l1 penalty
}

# GridSearchCV for Logistic Regression
grid_search_lr = GridSearchCV(estimator=LogisticRegression(random_state=42), 
                              param_grid=param_grid_lr, 
                              cv=5, scoring='roc_auc', n_jobs=-1)
grid_search_lr.fit(X_train, y_train)

print("Logistic Regression - Best Parameters:", grid_search_lr.best_params_)
print("Logistic Regression - Best AUC score:", grid_search_lr.best_score_)
# Out:
# Logistic Regression - Best Parameters: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# Logistic Regression - Best AUC score: 0.7312988719545761

# %%
# Using Best Parameters from GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, precision_score

best_params_lr = grid_search_lr.best_params_
log_reg = LogisticRegression(random_state=42, **best_params_lr)
log_reg.fit(X_train, y_train)
y_pred_lr = log_reg.predict(X_test)

auc_lr_GAD = roc_auc_score(y_test, y_pred_lr)
precision_lr_GAD = precision_score(y_test, y_pred_lr)

print(f"Logistic Regression AUC: {auc_lr_GAD:.3f}")
print(f"Logistic Regression Precision: {precision_lr_GAD:.3f}")
# Out:
# Logistic Regression AUC: 0.499
# Logistic Regression Precision: 0.000

# %%
importance_lr = log_reg.coef_[0]

# For interpretability, put them in a DataFrame
feature_names_lr = column_transformer.get_feature_names_out()
importance_lr_df = pd.DataFrame({'feature': feature_names_lr, 'importance': importance_lr}).sort_values('importance', ascending=False)

# Now visualize the feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='importance', y='feature', data=importance_lr_df.head(10))
plt.title('Logistic Regression Feature Importances')
plt.xlabel('Coefficient Value')
plt.ylabel('Feature')
plt.show()

# %%
# the magnitude of a SHAP value indicates the impact of a feature, and the sign indicates the direction of the impact (positive or negative).
explainer_lr = shap.LinearExplainer(log_reg, X_train)
shap_values_lr = explainer_lr.shap_values(X_train)
shap.summary_plot(shap_values_lr, X_train, feature_names=feature_names_lr)
# Out:
# Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.

# %% [markdown]
# ### Decision Tree/Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)

print(classification_report(y_test, rf_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8441    0.9727    0.9038      1464
#            1     0.3443    0.0739    0.1217       284
#
#     accuracy                         0.8267      1748
#    macro avg     0.5942    0.5233    0.5128      1748
# weighted avg     0.7629    0.8267    0.7768      1748

# %% [markdown]
# #### Parameter Tuning (GridSearchCV)

# %%
from sklearn.model_selection import GridSearchCV

# Parameter grid for Random Forest
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'class_weight': [None, 'balanced']
}

# gridsearchcv
rf = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, scoring='roc_auc', n_jobs=-1)

grid_search.fit(X_train, y_train)

print("Best parameters:", grid_search.best_params_)
print("Best AUC score:", grid_search.best_score_)
# Out:
# Best parameters: {'class_weight': None, 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 200}
# Best AUC score: 0.7283326257979496

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, precision_score

# Training with best parameters from grid search (class weight as 'balanced')
best_params_rf = grid_search.best_params_
rf = RandomForestClassifier(random_state=42, **best_params_rf)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

auc_rf_GAD = roc_auc_score(y_test, y_pred_rf)
precision_rf_GAD = precision_score(y_test, y_pred_rf)

print(f"Random Forest AUC: {auc_rf_GAD:.3f}")
print(f"Random Forest Precision: {precision_rf_GAD:.3f}")
# Out:
# Random Forest AUC: 0.500
# Random Forest Precision: 0.000
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
# Assuming rf is the trained RandomForestClassifier
importances = rf.feature_importances_

# To make the importances more interpretable, put them in a DataFrame
feature_names = column_transformer.get_feature_names_out()
importances_df = pd.DataFrame({'feature': feature_names, 'importance': importances}).sort_values('importance', ascending=False)

# Now you can visualize the feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='importance', y='feature', data=importances_df.head(10))
plt.title('Top 10 Feature Importances')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
nb_pred = nb_model.predict(X_test)
print(classification_report(y_test, nb_pred, digits=4, zero_division=1)) # UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# Out:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.0000    0.0000      1464
#            1     0.1625    1.0000    0.2795       284
#
#     accuracy                         0.1625      1748
#    macro avg     0.5812    0.5000    0.1398      1748
# weighted avg     0.8639    0.1625    0.0454      1748

# %% [markdown]
# #### Parameter Tuning (GridSearchCV)

# %%
from sklearn.naive_bayes import GaussianNB

# There typically aren't hyperparameters to tune for GaussianNB,
param_grid_nb = {
    'var_smoothing': [1e-9, 1e-8, 1e-7]  # Variance smoothing parameter
}

# GridSearchCV for Naive Bayes
grid_search_nb = GridSearchCV(estimator=GaussianNB(), 
                              param_grid=param_grid_nb, 
                              cv=5, scoring='roc_auc', n_jobs=-1)
grid_search_nb.fit(X_train, y_train)

print("Naive Bayes - Best Parameters:", grid_search_nb.best_params_)
print("Naive Bayes - Best AUC score:", grid_search_nb.best_score_)
# Out:
# Naive Bayes - Best Parameters: {'var_smoothing': 1e-09}
# Naive Bayes - Best AUC score: 0.5001737619461337

# %%
# Using Best Parameters from GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score, precision_score

best_params_nb = grid_search_nb.best_params_
naive_bayes = GaussianNB(**best_params_nb)
naive_bayes.fit(X_train, y_train)
y_pred_nb = naive_bayes.predict(X_test)

auc_nb_GAD = roc_auc_score(y_test, y_pred_nb)
precision_nb_GAD = precision_score(y_test, y_pred_nb)

print(f"Naive Bayes AUC: {auc_nb_GAD:.3f}")
print(f"Naive Bayes Precision: {precision_nb_GAD:.3f}")
# Out:
# Naive Bayes AUC: 0.500
# Naive Bayes Precision: 0.162

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC
svm_model = SVC()
svm_model.fit(X_train, y_train)
svm_pred = svm_model.predict(X_test)
print(classification_report(y_test, svm_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8374    0.9993    0.9112      1464
#            1     0.0000    0.0000    0.0000       284
#
#     accuracy                         0.8370      1748
#    macro avg     0.4187    0.4997    0.4556      1748
# weighted avg     0.7014    0.8370    0.7632      1748

# %% [markdown]
# #### Parameter Tuning (GridSearchCV)

# %%
from sklearn.svm import SVC

# Parameter grid for SVM
param_grid_svm = {
    'C': [0.1, 1, 10],  # Regularization parameter
    'gamma': ['scale', 'auto'],  # Kernel coefficient
    'kernel': ['rbf', 'linear']  # Specifies the kernel type to be used
}

# GridSearchCV for SVM
grid_search_svm = GridSearchCV(estimator=SVC(random_state=42), 
                               param_grid=param_grid_svm, 
                               cv=5, scoring='roc_auc', n_jobs=-1)
grid_search_svm.fit(X_train, y_train)

print("SVM - Best Parameters:", grid_search_svm.best_params_)
print("SVM - Best AUC score:", grid_search_svm.best_score_)
# Out:
# SVM - Best Parameters: {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# SVM - Best AUC score: 0.672993371895305

# %%
# Using Best Parameters from GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score, precision_score

best_params_svm = grid_search_svm.best_params_
svm = SVC(random_state=42, **best_params_svm)
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test)

auc_svm_GAD = roc_auc_score(y_test, y_pred_svm)
precision_svm_GAD = precision_score(y_test, y_pred_svm)

print(f"SVM AUC: {auc_svm_GAD:.3f}")
print(f"SVM Precision: {precision_svm_GAD:.3f}")
# Out:
# SVM AUC: 0.500
# SVM Precision: 0.000
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# ## Combined Anxieties

# %%
X_train, X_test, y_train, y_test = train_test_split(features_encoded, y3, test_size=0.2, random_state=42)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

log_reg = LogisticRegression(max_iter=1000)  
log_reg.fit(X_train, y_train)

# predictions & evaluation
y_pred = log_reg.predict(X_test)
print(classification_report(y_test, y_pred, digits=4))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.6137    0.6236    0.6186       874
#            1     0.6174    0.6076    0.6125       874
#
#     accuracy                         0.6156      1748
#    macro avg     0.6156    0.6156    0.6155      1748
# weighted avg     0.6156    0.6156    0.6155      1748
#
# [[545 329]
#  [343 531]]

# %% [markdown]
# #### Parameter Tuning (GridSearchCV)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# Parameter grid for Logistic Regression
param_grid_lr = {
    'C': [0.01, 0.1, 1, 10, 100],  # Regularization parameter
    'penalty': ['l1', 'l2'],  # Norm of penalty
    'solver': ['liblinear']  # Solver compatible with l1 penalty
}

# GridSearchCV for Logistic Regression
grid_search_lr = GridSearchCV(estimator=LogisticRegression(random_state=42), 
                              param_grid=param_grid_lr, 
                              cv=5, scoring='roc_auc', n_jobs=-1)
grid_search_lr.fit(X_train, y_train)

print("Logistic Regression - Best Parameters:", grid_search_lr.best_params_)
print("Logistic Regression - Best AUC score:", grid_search_lr.best_score_)
# Out:
# Logistic Regression - Best Parameters: {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
# Logistic Regression - Best AUC score: 0.6837267490380101

# %%
# Using Best Parameters from GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, precision_score

best_params_lr = grid_search_lr.best_params_
log_reg = LogisticRegression(random_state=42, **best_params_lr)
log_reg.fit(X_train, y_train)
y_pred_lr = log_reg.predict(X_test)

auc_lr_combined = roc_auc_score(y_test, y_pred_lr)
precision_lr_combined = precision_score(y_test, y_pred_lr)

print(f"Logistic Regression AUC: {auc_lr_combined:.3f}")
print(f"Logistic Regression Precision: {precision_lr_combined:.3f}")
# Out:
# Logistic Regression AUC: 0.616
# Logistic Regression Precision: 0.617

# %%
# Assuming log_reg is the trained LogisticRegression model and X_train is a standardized dataset
importance_lr = log_reg.coef_[0]

# For interpretability, put them in a DataFrame
feature_names_lr = column_transformer.get_feature_names_out()
importance_lr_df = pd.DataFrame({'feature': feature_names_lr, 'importance': importance_lr}).sort_values('importance', ascending=False)

# Now visualize the feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='importance', y='feature', data=importance_lr_df.head(10))
plt.title('Logistic Regression Feature Importances')
plt.xlabel('Coefficient Value')
plt.ylabel('Feature')
plt.show()

# %%
# the magnitude of a SHAP value indicates the impact of a feature, and the sign indicates the direction of the impact (positive or negative).
explainer_lr = shap.LinearExplainer(log_reg, X_train)
shap_values_lr = explainer_lr.shap_values(X_train)
shap.summary_plot(shap_values_lr, X_train, feature_names=feature_names_lr)
# Out:
# Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.

# %% [markdown]
# ### Decision Tree/Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)
print(classification_report(y_test, rf_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.6066    0.6476    0.6265       874
#            1     0.6221    0.5801    0.6004       874
#
#     accuracy                         0.6138      1748
#    macro avg     0.6144    0.6138    0.6134      1748
# weighted avg     0.6144    0.6138    0.6134      1748

# %% [markdown]
# #### Parameter Tuning (GridSearchCV)

# %%
from sklearn.model_selection import GridSearchCV

# Parameter grid for Random Forest
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'class_weight': [None, 'balanced']
}

# gridsearchcv
rf = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, scoring='roc_auc', n_jobs=-1)

grid_search.fit(X_train, y_train)

print("Best parameters:", grid_search.best_params_)
print("Best AUC score:", grid_search.best_score_)
# Out:
# Best parameters: {'class_weight': 'balanced', 'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 100}
# Best AUC score: 0.6800750345880827

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, precision_score

# Training with best parameters from grid search (class weight as 'balanced')
best_params_rf = grid_search.best_params_
rf = RandomForestClassifier(random_state=42, **best_params_rf)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

auc_rf_combined = roc_auc_score(y_test, y_pred_rf)
precision_rf_combined = precision_score(y_test, y_pred_rf)

print(f"Random Forest AUC: {auc_rf_combined:.3f}")
print(f"Random Forest Precision: {precision_rf_combined:.3f}")
# Out:
# Random Forest AUC: 0.617
# Random Forest Precision: 0.619

# %%
# Assuming rf is the trained RandomForestClassifier
importances = rf.feature_importances_

# To make the importances more interpretable, put them in a DataFrame
feature_names = column_transformer.get_feature_names_out()
importances_df = pd.DataFrame({'feature': feature_names, 'importance': importances}).sort_values('importance', ascending=False)

# Now you can visualize the feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='importance', y='feature', data=importances_df.head(10))
plt.title('Top 10 Feature Importances')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
nb_pred = nb_model.predict(X_test)
print(classification_report(y_test, nb_pred, digits=4, zero_division=1)) # UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# Out:
#               precision    recall  f1-score   support
#
#            0     0.5000    1.0000    0.6667       874
#            1     1.0000    0.0000    0.0000       874
#
#     accuracy                         0.5000      1748
#    macro avg     0.7500    0.5000    0.3333      1748
# weighted avg     0.7500    0.5000    0.3333      1748

# %% [markdown]
# #### Parameter Tuning (GridSearchCV)

# %%
from sklearn.naive_bayes import GaussianNB

# There typically aren't hyperparameters to tune for GaussianNB,
param_grid_nb = {
    'var_smoothing': [1e-9, 1e-8, 1e-7]  # Variance smoothing parameter
}

# GridSearchCV for Naive Bayes
grid_search_nb = GridSearchCV(estimator=GaussianNB(), 
                              param_grid=param_grid_nb, 
                              cv=5, scoring='roc_auc', n_jobs=-1)
grid_search_nb.fit(X_train, y_train)

print("Naive Bayes - Best Parameters:", grid_search_nb.best_params_)
print("Naive Bayes - Best AUC score:", grid_search_nb.best_score_)
# Out:
# Naive Bayes - Best Parameters: {'var_smoothing': 1e-09}
# Naive Bayes - Best AUC score: 0.6739592249660074

# %%
# Using Best Parameters from GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score, precision_score

best_params_nb = grid_search_nb.best_params_
naive_bayes = GaussianNB(**best_params_nb)
naive_bayes.fit(X_train, y_train)
y_pred_nb = naive_bayes.predict(X_test)

auc_nb_combined = roc_auc_score(y_test, y_pred_nb)
precision_nb_combined = precision_score(y_test, y_pred_nb)

print(f"Naive Bayes AUC: {auc_nb_combined:.3f}")
print(f"Naive Bayes Precision: {precision_nb_combined:.3f}")
# Out:
# Naive Bayes AUC: 0.500
# Naive Bayes Precision: 0.000
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC
svm_model = SVC()
svm_model.fit(X_train, y_train)
svm_pred = svm_model.predict(X_test)
print(classification_report(y_test, svm_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.6059    0.6384    0.6217       874
#            1     0.6179    0.5847    0.6008       874
#
#     accuracy                         0.6116      1748
#    macro avg     0.6119    0.6116    0.6113      1748
# weighted avg     0.6119    0.6116    0.6113      1748

# %% [markdown]
# #### Parameter Tuning (GridSearchCV)

# %%
from sklearn.svm import SVC

# Parameter grid for SVM
param_grid_svm = {
    'C': [0.1, 1, 10],  # Regularization parameter
    'gamma': ['scale', 'auto'],  # Kernel coefficient
    'kernel': ['rbf', 'linear']  # Specifies the kernel type to be used
}

# GridSearchCV for SVM
grid_search_svm = GridSearchCV(estimator=SVC(random_state=42), 
                               param_grid=param_grid_svm, 
                               cv=5, scoring='roc_auc', n_jobs=-1)
grid_search_svm.fit(X_train, y_train)

print("SVM - Best Parameters:", grid_search_svm.best_params_)
print("SVM - Best AUC score:", grid_search_svm.best_score_)
# Out:
# SVM - Best Parameters: {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# SVM - Best AUC score: 0.6626937548821741

# %%
# Using Best Parameters from GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score, precision_score

best_params_svm = grid_search_svm.best_params_
svm = SVC(random_state=42, **best_params_svm)
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test)

auc_svm_combined = roc_auc_score(y_test, y_pred_svm)
precision_svm_combined = precision_score(y_test, y_pred_svm)

print(f"SVM AUC: {auc_svm_combined:.3f}")
print(f"SVM Precision: {precision_svm_combined:.3f}")
# Out:
# SVM AUC: 0.611
# SVM Precision: 0.603

# %% [markdown]
# ### Mapping

# %%
""" # mapping for Platform
platform_mapping = {
    'PC': 1,
    'Console (PS, Xbox, ...)': 2,
    'Smartphone / Tablet': 3,
    'Extremely difficult': 4
}

# Map the categorical labels to integers
df['Platform'] = df['Platform'].map(platform_mapping) """
# Out:
# " # mapping for Platform\nplatform_mapping = {\n    'PC': 1,\n    'Console (PS, Xbox, ...)': 2,\n    'Smartphone / Tablet': 3,\n    'Extremely difficult': 4\n}\n\n# Map the categorical labels to integers\ndf['Platform'] = df['Platform'].map(platform_mapping) "

# %%
""" # mapping for GADE
difficulty_mapping = {
    'Not difficult at all': 1,
    'Somewhat difficult': 2,
    'Very difficult': 3,
    'Extremely difficult': 4
}

# Map the categorical labels to integers
df['GADE'] = df['GADE'].map(difficulty_mapping) """
# Out:
# " # mapping for GADE\ndifficulty_mapping = {\n    'Not difficult at all': 1,\n    'Somewhat difficult': 2,\n    'Very difficult': 3,\n    'Extremely difficult': 4\n}\n\n# Map the categorical labels to integers\ndf['GADE'] = df['GADE'].map(difficulty_mapping) "

# %%
""" # mapping for Game
game_mapping = {
    'League of Legends': 1,
    'Starcraft 2': 3,
    'Counter Strike': 4,
    'World of Warcraft': 5,
    'Hearthstone': 6,
    'Diablo 3': 7,
    'Heroes of the Storm': 8,
    'Guild Wars 2': 9,
    'Destiny': 10,
    'Skyrim': 11,
    'Other': 12,
}

# Map the categorical labels to integers
df['Game'] = df['Game'].map(game_mapping) """
# Out:
# " # mapping for Game\ngame_mapping = {\n    'League of Legends': 1,\n    'Starcraft 2': 3,\n    'Counter Strike': 4,\n    'World of Warcraft': 5,\n    'Hearthstone': 6,\n    'Diablo 3': 7,\n    'Heroes of the Storm': 8,\n    'Guild Wars 2': 9,\n    'Destiny': 10,\n    'Skyrim': 11,\n    'Other': 12,\n}\n\n# Map the categorical labels to integers\ndf['Game'] = df['Game'].map(game_mapping) "

# %% [markdown]
# ## Model Evaluations

# %% [markdown]
# ### Social Anxiety

# %%
# performance scores for each model using best parameters
performance_SA = {
    'Model': ['Logistic Regression', 'Random Forest', 'Naive Bayes', 'SVM'],
    'AUC': [auc_lr_SA, auc_rf_SA, auc_nb_SA, auc_svm_SA],
    'Precision': [precision_lr_SA, precision_rf_SA, precision_nb_SA, precision_svm_SA]
}

df_results = pd.DataFrame(performance_SA)
df_results
# Out:
#                  Model       AUC  Precision
# 0  Logistic Regression  0.607588   0.569427
# 1        Random Forest  0.606586   0.556962
# 2          Naive Bayes  0.500000   0.000000
# 3                  SVM  0.586453   0.612069

# %%
# AUC scores
plt.figure(figsize=(7, 3))
auc_plot = sns.barplot(x='Model', y='AUC', data=df_results)
plt.title('Comparison of AUC Scores')
plt.ylabel('AUC Score')
plt.xlabel('Model')
plt.show()

# %%
# Precision
plt.figure(figsize=(7, 3))
precision_plot = sns.barplot(x='Model', y='Precision', data=df_results)
plt.title('Comparison of Precision Scores')
plt.ylabel('Precision Score')
plt.xlabel('Model')
plt.show()

# %% [markdown]
# ### Generalized Anxiety

# %%
# performance scores for each model using best parameters
performance_GAD = {
    'Model': ['Logistic Regression', 'Random Forest', 'Naive Bayes', 'SVM'],
    'AUC': [auc_lr_GAD, auc_rf_GAD, auc_nb_GAD, auc_svm_GAD],
    'Precision': [precision_lr_GAD, precision_rf_GAD, precision_nb_GAD, precision_svm_GAD]
}

df_results = pd.DataFrame(performance_GAD)
df_results
# Out:
#                  Model       AUC  Precision
# 0  Logistic Regression  0.499317   0.000000
# 1        Random Forest  0.500000   0.000000
# 2          Naive Bayes  0.500000   0.162471
# 3                  SVM  0.500000   0.000000

# %%
# AUC scores
plt.figure(figsize=(7, 3))
auc_plot = sns.barplot(x='Model', y='AUC', data=df_results)
plt.title('Comparison of AUC Scores')
plt.ylabel('AUC Score')
plt.xlabel('Model')
plt.show()

# %%
# Precision
plt.figure(figsize=(7, 3))
precision_plot = sns.barplot(x='Model', y='Precision', data=df_results)
plt.title('Comparison of Precision Scores')
plt.ylabel('Precision Score')
plt.xlabel('Model')
plt.show()

# %% [markdown]
# ### Combined Anxieties

# %%
# performance scores for each model using best parameters
performance_combined = {
    'Model': ['Logistic Regression', 'Random Forest', 'Naive Bayes', 'SVM'],
    'AUC': [auc_lr_combined, auc_rf_combined, auc_nb_combined, auc_svm_combined],
    'Precision': [precision_lr_combined, precision_rf_combined, precision_nb_combined, precision_svm_combined]
}

df_results = pd.DataFrame(performance_combined)
df_results
# Out:
#                  Model       AUC  Precision
# 0  Logistic Regression  0.615561   0.617442
# 1        Random Forest  0.616705   0.619438
# 2          Naive Bayes  0.500000   0.000000
# 3                  SVM  0.610984   0.602972

# %%
# AUC scores
plt.figure(figsize=(7, 3))
auc_plot = sns.barplot(x='Model', y='AUC', data=df_results)
plt.title('Comparison of AUC Scores')
plt.ylabel('AUC Score')
plt.xlabel('Model')
plt.show()

# %%
# Precision
plt.figure(figsize=(7, 3))
precision_plot = sns.barplot(x='Model', y='Precision', data=df_results)
plt.title('Comparison of Precision Scores')
plt.ylabel('Precision Score')
plt.xlabel('Model')
plt.show()
